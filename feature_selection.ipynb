# %%
from sklearn.datasets import load_breast_cancer
import pandas as pd
import numpy as np
from numpy import set_printoptions
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif

# %% [markdown]
# ## LOAD DATASET

# %%
dataset = load_breast_cancer()
data = pd.DataFrame(dataset['data'], columns=dataset['feature_names'])
data['target'] = dataset['target']

# %%
data.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                 0.07871  ...          17.33           184.60      2019.0
# 1                 0.05667  ...          23.41           158.80      1956.0
# 2                 0.05999  ...          25.53           152.50      1709.0
# 3                 0.09744  ...          26.50            98.87       567.7
# 4                 0.05883  ...          16.67           152.20      1575.0
#
#    worst smoothness  worst compactness  worst concavity  worst concave points  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    worst symmetry  worst fractal dimension  target
# 0          0.4601                  0.11890       0
# 1          0.2750                  0.08902       0
# 2          0.3613                  0.08758       0
# 3          0.6638                  0.17300       0
# 4          0.2364                  0.07678       0
#
# [5 rows x 31 columns]

# %%
data.shape
# Out:
# (569, 31)

# %%
data.target.value_counts() / len(data)
# Out:
# 1    0.627417
# 0    0.372583
# Name: target, dtype: float64

# %% [markdown]
# ## FEATURE SELECTION

# %% [markdown]
# ### Univariate Selection

# %%
X = data.iloc[:, 0:(len(data.columns)-1)]
Y = data.iloc[:,-1]

# %% [markdown]
# feature extraction

# %%
# 4 is the number of best features we desired
un_selection = SelectKBest(score_func=f_classif, k=4)

# %%
un_fit = un_selection.fit(X, Y)

# %% [markdown]
# summarize scores

# %%
set_printoptions(precision=3)

# %%
scores = pd.DataFrame(data=np.column_stack((data.columns[:-1], un_fit.scores_)), 
                      columns=['colname', 'score'])

# %%
scores = scores.sort_values(by='score', ascending=False)

# %%
scores
# Out:
#                     colname      score
# 27     worst concave points    964.385
# 22          worst perimeter    897.944
# 7       mean concave points    861.676
# 20             worst radius    860.782
# 2            mean perimeter    697.235
# 23               worst area      661.6
# 0               mean radius    646.981
# 3                 mean area    573.061
# 6            mean concavity    533.793
# 26          worst concavity    436.692
# 5          mean compactness    313.233
# 25        worst compactness    304.341
# 10             radius error     268.84
# 12          perimeter error    253.897
# 13               area error    243.652
# 21            worst texture    149.597
# 24         worst smoothness    122.473
# 28           worst symmetry     118.86
# 1              mean texture    118.096
# 17     concave points error    113.263
# 4           mean smoothness    83.6511
# 8             mean symmetry    69.5274
# 29  worst fractal dimension     66.444
# 15        compactness error    53.2473
# 16          concavity error    39.0145
# 19  fractal dimension error    3.46827
# 14         smoothness error    2.55797
# 9    mean fractal dimension  0.0934593
# 11            texture error  0.0390947
# 18           symmetry error  0.0241174

# %% [markdown]
# summarize selected features

# %%
features = un_fit.transform(X)

# %%
print(features[0:5,:])
# Out:
# [[1.471e-01 2.538e+01 1.846e+02 2.654e-01]
#  [7.017e-02 2.499e+01 1.588e+02 1.860e-01]
#  [1.279e-01 2.357e+01 1.525e+02 2.430e-01]
#  [1.052e-01 1.491e+01 9.887e+01 2.575e-01]
#  [1.043e-01 2.254e+01 1.522e+02 1.625e-01]]

# %% [markdown]
# ### Recursive Feature Elimination

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
from warnings import filterwarnings
filterwarnings('ignore')

# %%
model = LogisticRegression(solver='lbfgs')
# 5 is the number of best feature we desired
rfe = RFE(model, 10)
rfe_fit = rfe.fit(X, Y)
print("Num Features: %d" % rfe_fit.n_features_)
print("Selected Features: %s" % rfe_fit.support_)
print("Feature Ranking: %s" % rfe_fit.ranking_)
# Out:
# Num Features: 10
# Selected Features: [ True False False False False False  True  True False False  True  True
#   True False False False False False False False False False False False
#  False  True  True  True  True False]
# Feature Ranking: [ 1 12 15 19 11  4  1  1  9 18  1  1  1  6 21  5 13 16 17 20 10  2  3 14
#   8  1  1  1  1  7]

# %%
RFE_rank = pd.DataFrame(data=np.column_stack((rfe_fit.ranking_, data.columns[:-1])), 
             columns=['ranking', 'colname'])

# %%
RFE_rank.sort_values(by='ranking', ascending=True)
# Out:
#    ranking                  colname
# 0        1              mean radius
# 27       1     worst concave points
# 26       1          worst concavity
# 25       1        worst compactness
# 6        1           mean concavity
# 7        1      mean concave points
# 10       1             radius error
# 11       1            texture error
# 12       1          perimeter error
# 28       1           worst symmetry
# 21       2            worst texture
# 22       3          worst perimeter
# 5        4         mean compactness
# 15       5        compactness error
# 13       6               area error
# 29       7  worst fractal dimension
# 24       8         worst smoothness
# 8        9            mean symmetry
# 20      10             worst radius
# 4       11          mean smoothness
# 1       12             mean texture
# 16      13          concavity error
# 23      14               worst area
# 2       15           mean perimeter
# 17      16     concave points error
# 18      17           symmetry error
# 9       18   mean fractal dimension
# 3       19                mean area
# 19      20  fractal dimension error
# 14      21         smoothness error
